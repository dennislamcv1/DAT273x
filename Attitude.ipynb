# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("attitude.csv", index_col='Unnamed: 0')

# %%
df
# Out:
#     attitude
# 0   2.725478
# 1   2.279837
# 2   5.830846
# 3  -0.444898
# 4   0.828241
# ..       ...
# 95  1.079155
# 96  4.136870
# 97  4.509649
# 98  3.389122
# 99 -0.326108
#
# [100 rows x 1 columns]

# %%
plt.figure(figsize=(12,9))
plt.plot(df);
